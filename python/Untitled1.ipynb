# %%
import pandas as pd
import seaborn as sns

# %%
d = pd.read_csv("test_data_025_125_20.csv")
d2 = pd.read_csv("test_data_025_125_20_flat_needle_water.csv")
d3 = pd.read_csv("test_data_025_125_20_flat_needle_soap.csv")
d4 = pd.read_csv("test_data_025_125_20_sharp_needle_soap.csv")
d5 = pd.read_csv("test_data_1_5_20_sharp_needle.csv")
d6 = pd.read_csv("test_data_1_5_20_flat_needle_single.csv")

# %%
sns.set(rc={'figure.figsize':(20,10)})

# %%
sns.lineplot(data=d[["mkm_passed", "diff_pa_aver"]], x="mkm_passed", y="diff_pa_aver")
# Out:
# <AxesSubplot:xlabel='mkm_passed', ylabel='diff_pa_aver'>

# %%
import numpy as np

# %%
d.groupby("mkm_passed").agg(
    {
        "diff_pa_aver": [np.mean, np.median, np.var, np.std]
    }
).reset_index().loc[90:110]
# Out:
#     mkm_passed diff_pa_aver
#                        mean median       var       std
# 90      9000.0     1.192632   1.19  0.061598  0.248190
# 91      9100.0     1.203158   1.16  0.059967  0.244882
# 92      9200.0     1.210000   1.23  0.079089  0.281227
# 93      9300.0     1.172632   1.10  0.079865  0.282604
# 94      9400.0     1.197368   1.15  0.071109  0.266663
# 95      9500.0     1.218947   1.20  0.072321  0.268926
# 96      9600.0     1.151053   1.11  0.079688  0.282290
# 97      9700.0     1.194211   1.19  0.072426  0.269120
# 98      9800.0     1.212105   1.20  0.081940  0.286251
# 99      9900.0     1.185789   1.18  0.095604  0.309198
# 100    10000.0     1.538947   1.16  2.047532  1.430920
# 101    10100.0     1.218421   1.22  0.052470  0.229062
# 102    10200.0     1.146316   1.05  0.128402  0.358333
# 103    10300.0     1.038947   1.07  0.132343  0.363790
# 104    10400.0     0.963158   1.08  0.071856  0.268060
# 105    10500.0     0.853684   0.77  0.088558  0.297587
# 106    10600.0     0.715789   0.65  0.040292  0.200730
# 107    10700.0     0.715263   0.69  0.029237  0.170990
# 108    10800.0     0.710526   0.70  0.026405  0.162497
# 109    10900.0     0.670526   0.66  0.022805  0.151014
# 110    11000.0     1.274250   0.71  3.388888  1.840893

# %%
sns.lineplot(data=d2[["mkm_passed", "diff_pa_aver"]], x="mkm_passed", y="diff_pa_aver")
# Out:
# <AxesSubplot:xlabel='mkm_passed', ylabel='diff_pa_aver'>

# %%
d2.groupby("mkm_passed").agg(
    {
        "diff_pa_aver": [np.mean, np.median, np.var, np.std]
    }
).reset_index().loc[60:85]
# Out:
#    mkm_passed diff_pa_aver
#                       mean median       var       std
# 60     6000.0     0.948947   0.98  0.044899  0.211893
# 61     6100.0     0.944737   0.94  0.043893  0.209507
# 62     6200.0     0.956842   0.97  0.051523  0.226986
# 63     6300.0     0.931053   0.92  0.046821  0.216382
# 64     6400.0     0.933158   0.90  0.041634  0.204044
# 65     6500.0     0.942632   0.92  0.052932  0.230069
# 66     6600.0     0.937368   0.95  0.050865  0.225533
# 67     6700.0     0.920000   0.88  0.042544  0.206263
# 68     6800.0     0.938421   0.94  0.056136  0.236931
# 69     6900.0     0.942632   0.95  0.054665  0.233805
# 70     7000.0     0.925789   0.89  0.041248  0.203096
# 71     7100.0     0.953158   0.93  0.041712  0.204234
# 72     7200.0     0.933684   0.93  0.044791  0.211639
# 73     7300.0     0.916842   0.87  0.041556  0.203853
# 74     7400.0     0.932632   0.91  0.036443  0.190900
# 75     7500.0     0.933684   0.93  0.046925  0.216621
# 76     7600.0     0.926316   0.91  0.042925  0.207182
# 77     7700.0     0.681579   0.65  0.064281  0.253536
# 78     7800.0     0.590526   0.48  0.071372  0.267155
# 79     7900.0     0.475789   0.45  0.016848  0.129800
# 80     8000.0     0.456316   0.42  0.017036  0.130521
# 81     8100.0     0.462632   0.44  0.016954  0.130207
# 82     8200.0     0.461053   0.46  0.017343  0.131694
# 83     8300.0     0.433684   0.40  0.015647  0.125087
# 84     8400.0     0.445789   0.45  0.014092  0.118711
# 85     8500.0     0.437368   0.45  0.015765  0.125558

# %%
sns.lineplot(data=d3[["mkm_passed", "diff_pa_aver"]], x="mkm_passed", y="diff_pa_aver")
# Out:
# <AxesSubplot:xlabel='mkm_passed', ylabel='diff_pa_aver'>

# %%
sns.lineplot(data=d4[["mkm_passed", "diff_pa_aver"]], x="mkm_passed", y="diff_pa_aver")
# Out:
# <AxesSubplot:xlabel='mkm_passed', ylabel='diff_pa_aver'>

# %%
sns.lineplot(data=d5[["mkm_passed", "diff_pa_aver"]], x="mkm_passed", y="diff_pa_aver")
# Out:
# <AxesSubplot:xlabel='mkm_passed', ylabel='diff_pa_aver'>

# %%
sns.lineplot(data=d6[["mkm_passed", "diff_pa_aver"]], x="mkm_passed", y="diff_pa_aver")
# Out:
# <AxesSubplot:xlabel='mkm_passed', ylabel='diff_pa_aver'>
